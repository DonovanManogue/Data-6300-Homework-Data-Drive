# %% [markdown]
# # HW01 – Introduction to Python and Pandas

# %% [markdown]
# ### By Donovan Manogue

# %% [markdown]
# ## Section 3 Import Libraries

# %%
import numpy as np
import pandas as pd
#importing the necessarry libraries for this homework.

# %% [markdown]
# ## Section 4 Import Data

# %%
df_realestate= pd.read_csv('/Users/donovanmanogue/Documents/HW01/data/Real Estate Data.csv', index_col=0, header=0)

#importing the realestate data and creating a dataframe for the data.

# %% [markdown]
# ## Section 5 View Data

# %%
df_realestate.head(5)
# Out:
#                     Type       Zoning Class  Lot Frontage  Lot Area Alley  \
# Id
# 1   2-STORY 1946 & NEWER  Resid Low Density          65.0      8450   NaN
# 2   1-STORY 1946 & NEWER  Resid Low Density          80.0      9600   NaN
# 3   2-STORY 1946 & NEWER  Resid Low Density          68.0     11250   NaN
# 4   2-STORY 1945 & OLDER  Resid Low Density          60.0      9550   NaN
# 5   2-STORY 1946 & NEWER  Resid Low Density          84.0     14260   NaN
#
#              Lot Shape Land Contour           Lot Config Land Slope  \
# Id
# 1              Regular        Level           Inside lot     Gentle
# 2              Regular        Level  Frontage on 2 sides     Gentle
# 3   Slightly irregular        Level           Inside lot     Gentle
# 4   Slightly irregular        Level           Corner lot     Gentle
# 5   Slightly irregular        Level  Frontage on 2 sides     Gentle
#
#              Nbhd  ... Open Porch Area Enclosed Porch Area  \
# Id                 ...
# ...

# %%
df_realestate.sample()
# Out:
#                     Type       Zoning Class  Lot Frontage  Lot Area Alley  \
# Id
# 704  2 FAMILY CONVERSION  Resid Med Density          76.0      7630   NaN
#
#     Lot Shape Land Contour  Lot Config Land Slope      Nbhd  ...  \
# Id                                                           ...
# 704   Regular        Level  Inside lot     Gentle  Old Town  ...
#
#     Open Porch Area Enclosed Porch Area 3 Season Porch Area  \
# Id
# 704               0                  40                   0
#
#      Screen Porch Area  Pool Area  Pool Qual            Fence  \
# Id
# 704                  0          0    No Pool  Minimum Privacy
#
#                         Sale Type Sale Condition Sale Price
# Id
# 704  Warranty Deed - Conventional    Normal Sale     140000
#
# [1 rows x 68 columns]

# %%
df_realestate.tail(2)
# Out:
#                       Type       Zoning Class  Lot Frontage  Lot Area Alley  \
# Id
# 1459  1-STORY 1946 & NEWER  Resid Low Density          68.0      9717   NaN
# 1460  1-STORY 1946 & NEWER  Resid Low Density          75.0      9937   NaN
#
#      Lot Shape Land Contour  Lot Config Land Slope        Nbhd  ...  \
# Id                                                              ...
# 1459   Regular        Level  Inside lot     Gentle  North Ames  ...
# 1460   Regular        Level  Inside lot     Gentle     Edwards  ...
#
#      Open Porch Area Enclosed Porch Area 3 Season Porch Area  \
# Id
# 1459               0                 112                   0
# 1460              68                   0                   0
#
#       Screen Porch Area  Pool Area  Pool Qual     Fence  \
# Id
# 1459                  0          0    No Pool  No Fence
# 1460                  0          0    No Pool  No Fence
#
#                          Sale Type Sale Condition Sale Price
# Id
# ...

# %%
df_realestate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1404 entries, 1 to 1460
# Data columns (total 68 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Type                      1404 non-null   object
#  1   Zoning Class              1404 non-null   object
#  2   Lot Frontage              1151 non-null   float64
#  3   Lot Area                  1404 non-null   int64
#  4   Alley                     84 non-null     object
#  5   Lot Shape                 1404 non-null   object
#  6   Land Contour              1404 non-null   object
#  7   Lot Config                1404 non-null   object
#  8   Land Slope                1404 non-null   object
#  9   Nbhd                      1404 non-null   object
#  10  Location Condition        1404 non-null   object
#  11  Bldg Type                 1404 non-null   object
#  12  House Style               1404 non-null   object
# ...

# %%
#In section 5 I executed a block a few blocks of code to view the top 5 rows, a sample of the records, 
#the bottom 2 rows, and to look at all the information on the dataframe

# %% [markdown]
# ## Section 6 Drop and Rename Columns

# %%
df_realestate = df_realestate.drop(df_realestate.columns[[1,5,7,8,11,12,17,18,19,20,22,23,24,25,26,27,28,32,33,34,46,48,49,54,55,56,63,64,65,16]],axis=1)

# %%
df_realestate = df_realestate.rename(columns ={'Type':'Dwelling Type', \
                                               'OvQual':'Overall Quality', \
                                               'Nbhd':'Neighborhood', \
                                               'Built':'Year Built'})

# %%
df_realestate.shape
# Out:
# (1404, 38)

# %%
#In section 6 I executed one blocks of code to drop columns for us to perform our analysis. I decided to use the index number, to make it easier than to type out every single column, but if someone wanted to, they could do it that way.
#Also, went through the columns and decided to change some of the abbreviates and some of the names to make it all make more sense.
#To do that I executed one line of code to go ahead and change the name of the columns within the dataframe.

# %% [markdown]
# ## Section 7 Grouping the data and replacing Values

# %% [markdown]
# ### 7a Group based on 'Neighborhood' and replace values

# %%
df_realestate.groupby('Neighborhood').count()
# Out:
#                             Dwelling Type  Lot Frontage  Lot Area  Alley  \
# Neighborhood
# Bloomington Heights                     6             4         6      0
# Bloomington Hts                        11            10        11      0
# Bluestem                                2             2         2      0
# Briardale                              16            16        16      0
# Brookside                              49            44        49      5
# Clear Creek                            27            13        27      0
# College Creek                         150           126       150      0
# Crawford                               50            40        50      1
# Edwards                                89            81        89      6
# Gilbert                                79            49        79      0
# Iowa DOT and Rail Road                 34            31        34      6
# Meadow Village                         10             8        10      0
# ...

# %%
df_realestate = df_realestate.replace('Bloomington Hts', 'Bloomington Heights')

# %%
df_realestate.groupby('Neighborhood')['Sale Price'].median()
# Out:
# Neighborhood
# Bloomington Heights           191000.0
# Bluestem                      137500.0
# Briardale                     106000.0
# Brookside                     128000.0
# Clear Creek                   200000.0
# College Creek                 197200.0
# Crawford                      208812.0
# Edwards                       120000.0
# Gilbert                       181000.0
# Iowa DOT and Rail Road        104750.0
# Meadow Village                106000.0
# Mitchell                      154750.0
# North Ames                    141000.0
# Northpark Villa               146000.0
# Northridge                    301500.0
# Northridge Heights            315000.0
# Northwest Ames                182900.0
# Old Town                      119900.0
# Sawyer                        135000.0
# Sawyer West                   179950.0
# Somerset                      225500.0
# South & West of Iowa State    139750.0
# Stone Brook                   278000.0
# Timberland                    233975.0
# ...

# %%
#In this section I grouped together all the data by the neighbordhoods, and replaced one of the neighborhoods that was mispelled.
#I made sure to replace it with the correctly spelled neighborhood.
#Then I grouped the data frame by the neighborhood again, but only wanted to see one column, that being the Sale Price column.
#I grouped it by the sale price, then made sure to get the medium price for each neighborhood.

# %% [markdown]
# ### 7b Group based on 'Dwelling Type' and replace values

# %%
df_realestate.groupby('Dwelling Type')['Dwelling Type'].count()
# Out:
# Dwelling Type
# 1 STORY PUD               9
# 1-1/2 STORY ALL AGES    138
# 1-STORY 1945 & OLDER     62
# 1-STORY 1946 & NEWER    531
# 1-STORY PUD              78
# 2 FAMILY CONVERSION      28
# 2-1/2 STORY ALL AGES     15
# 2-STORY 1945 & OLDER     59
# 2-STORY 1946 & NEWER    298
# 2-STORY PUD              63
# DUPLEX                   46
# SPLIT FOYER              20
# SPLIT OR MULTI-LEVEL     57
# Name: Dwelling Type, dtype: int64

# %%
df_realestate = df_realestate.replace('1-STORY PUD','1 STORY PUD')

# %%
df_realestate.groupby(['Neighborhood','Dwelling Type'])['Sale Price'].median()
# Out:
# Neighborhood         Dwelling Type
# Bloomington Heights  1 STORY PUD             191500.0
#                      1-STORY 1946 & NEWER    159895.0
# Bluestem             2-STORY PUD             137500.0
# Briardale            2-STORY PUD             106000.0
# Brookside            1-1/2 STORY ALL AGES    132500.0
#                                                ...
# Timberland           SPLIT OR MULTI-LEVEL    181250.0
# Veenker              1 STORY PUD             270000.0
#                      1-STORY 1946 & NEWER    181500.0
#                      2-STORY 1946 & NEWER    294000.0
#                      SPLIT OR MULTI-LEVEL    190500.0
# Name: Sale Price, Length: 132, dtype: float64

# %%
#In section 7b I did the same things I did in section 7a where I grouped and renamed some of the values in the columns
#The difference in this section is that I had to group two different columns together by their sale price and get their median

# %% [markdown]
# ## 8. Summarize and Filter Data

# %% [markdown]
# ### Section 8a: Pivot Neighborhood and Land Contour

# %%
df_re_pivot = df_realestate.pivot_table(index='Neighborhood', columns='Land Contour', values='Sale Price')
df_re_pivot
# Out:
# Land Contour                       Banked     Depression       Hillside  \
# Neighborhood
# Bloomington Heights                   NaN            NaN            NaN
# Bluestem                              NaN            NaN            NaN
# Briardale                             NaN            NaN            NaN
# Brookside                   165400.000000   39300.000000   82500.000000
# Clear Creek                 220250.000000  222666.666667  186500.000000
# College Creek               124900.000000  140666.666667  124000.000000
# Crawford                    198656.250000  224000.000000  221900.000000
# Edwards                     147035.714286   72950.000000   94750.000000
# Gilbert                     154500.000000            NaN  247640.625000
# Iowa DOT and Rail Road      108978.600000   94500.000000  102776.000000
# Meadow Village                        NaN            NaN            NaN
# Mitchell                    134000.000000  148200.000000  122625.000000
# ...

# %%
#I created a pivot table for the Neighborhoods and the type of land contour they had

# %% [markdown]
# ### Section 8b: Describe and Filter for Garage Cars

# %%
df_realestate['Garage Cars'].describe()
# Out:
# count    1399.000000
# mean        1.789850
# std         0.717758
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         3.000000
# Name: Garage Cars, dtype: float64

# %%
df_realestate=df_realestate[df_realestate['Garage Cars'] <= 3]
df_realestate['Garage Cars'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1399 entries, 1 to 1460
# Series name: Garage Cars
# Non-Null Count  Dtype
# --------------  -----
# 1399 non-null   int64
# dtypes: int64(1)
# memory usage: 21.9 KB

# %%
df_realestate=df_realestate.drop(columns='Garage Cars')

# %%
#In this portion I described the garage cars column, and I made sure to get rid of any data from that column that was more thann 3 cars, then I dropped the column completely.

# %% [markdown]
# ### Section 8c: Describe and Filter for Sale Price

# %%
df_realestate['Sale Price'].describe()
# Out:
# count      1399.000000
# mean     183887.932094
# std       79325.966763
# min       34900.000000
# 25%      132500.000000
# 50%      165500.000000
# 75%      215100.000000
# max      755000.000000
# Name: Sale Price, dtype: float64

# %%
df_realestate[df_realestate['Sale Price'] > 500000]
# Out:
#              Dwelling Type  Lot Frontage  Lot Area Alley Land Contour  \
# Id
# 179   1-STORY 1946 & NEWER          63.0     17423   NaN        Level
# 441   1-STORY 1946 & NEWER         105.0     15431   NaN        Level
# 692   2-STORY 1946 & NEWER         104.0     21535   NaN        Level
# 770   2-STORY 1946 & NEWER          47.0     53504   NaN     Hillside
# 804   2-STORY 1946 & NEWER         107.0     13891   NaN        Level
# 899   1-STORY 1946 & NEWER         100.0     12919   NaN        Level
# 1047  2-STORY 1946 & NEWER          85.0     16056   NaN        Level
# 1170  2-STORY 1946 & NEWER         118.0     35760   NaN        Level
# 1183  2-STORY 1946 & NEWER         160.0     15623   NaN        Level
#
#             Neighborhood Location Condition  Overall Quality  Overall Cond  \
# Id
# 179          Stone Brook             Normal                9             5
# 441   Northridge Heights             Normal               10             5
# ...

# %%
df_realestate.sort_values(by=['Sale Price'], ascending= False)
# Out:
#              Dwelling Type  Lot Frontage  Lot Area Alley Land Contour  \
# Id
# 692   2-STORY 1946 & NEWER         104.0     21535   NaN        Level
# 1183  2-STORY 1946 & NEWER         160.0     15623   NaN        Level
# 1170  2-STORY 1946 & NEWER         118.0     35760   NaN        Level
# 899   1-STORY 1946 & NEWER         100.0     12919   NaN        Level
# 804   2-STORY 1946 & NEWER         107.0     13891   NaN        Level
# ...                    ...           ...       ...   ...          ...
# 1326  1-STORY 1945 & OLDER          40.0      3636   NaN        Level
# 31    2-STORY 1945 & OLDER          50.0      8500  Pave        Level
# 534   1-STORY 1946 & NEWER          50.0      5000   NaN   Depression
# 917   1-STORY 1946 & NEWER          50.0      9000   NaN        Level
# 496   1-STORY 1945 & OLDER          60.0      7879   NaN        Level
#
#                 Neighborhood  Location Condition  Overall Quality  \
# Id
# ...

# %%
df_re_over500k = df_realestate[df_realestate['Sale Price'] > 500000]
df_re_over500k
# Out:
#              Dwelling Type  Lot Frontage  Lot Area Alley Land Contour  \
# Id
# 179   1-STORY 1946 & NEWER          63.0     17423   NaN        Level
# 441   1-STORY 1946 & NEWER         105.0     15431   NaN        Level
# 692   2-STORY 1946 & NEWER         104.0     21535   NaN        Level
# 770   2-STORY 1946 & NEWER          47.0     53504   NaN     Hillside
# 804   2-STORY 1946 & NEWER         107.0     13891   NaN        Level
# 899   1-STORY 1946 & NEWER         100.0     12919   NaN        Level
# 1047  2-STORY 1946 & NEWER          85.0     16056   NaN        Level
# 1170  2-STORY 1946 & NEWER         118.0     35760   NaN        Level
# 1183  2-STORY 1946 & NEWER         160.0     15623   NaN        Level
#
#             Neighborhood Location Condition  Overall Quality  Overall Cond  \
# Id
# 179          Stone Brook             Normal                9             5
# 441   Northridge Heights             Normal               10             5
# ...

# %%
df_re_over500k.iloc[:,[0,5,36]].head()
# Out:
#             Dwelling Type        Neighborhood  Sale Price
# Id
# 179  1-STORY 1946 & NEWER         Stone Brook      501837
# 441  1-STORY 1946 & NEWER  Northridge Heights      555000
# 692  2-STORY 1946 & NEWER          Northridge      755000
# 770  2-STORY 1946 & NEWER         Stone Brook      538000
# 804  2-STORY 1946 & NEWER  Northridge Heights      582933

# %%
df_realestate=df_realestate[df_realestate['Sale Price'] < 500000]
df_realestate['Sale Price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1390 entries, 1 to 1460
# Series name: Sale Price
# Non-Null Count  Dtype
# --------------  -----
# 1390 non-null   int64
# dtypes: int64(1)
# memory usage: 21.7 KB

# %%
#In this section I Filtered and Described Sale Price, while also creating another data frame for it as well.

# %% [markdown]
# ## 9. Save df_realestate as a csv

# %%
df_realestate.to_csv(r'/Users/donovanmanogue/Documents/HW01/data/Real Estate Data - Week2.csv')

# %%
#this is how I saved the dataframe as a csv file and put it into my Data folder
